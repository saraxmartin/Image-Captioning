# %%
import pandas as pd


df = pd.read_csv("captions.csv")

df.head()
# Out:
#        image_name  comment_number  \
# 0  1000092795.jpg               0
# 1  1000092795.jpg               1
# 2  1000092795.jpg               2
# 3  1000092795.jpg               3
# 4  1000092795.jpg               4
#
#                                             comment;
# 0   Two young guys with shaggy hair look at their...
# 1   Two young  White males are outside near many ...
# 2   Two men in green shirts are standing in a yar...
# 3      A man in a blue shirt standing in a garden .;
# 4           Two friends enjoy time spent together .;

# %%
# Remove trailing semicolons from all column values
df = df.applymap(lambda x: str(x).rstrip(';') if isinstance(x, str) else x)
df.head(20)
# Out:
# C:\Users\sara0\AppData\Local\Temp\ipykernel_4340\1477385087.py:2: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: str(x).rstrip(';') if isinstance(x, str) else x)
#         image_name  comment_number  \
# 0   1000092795.jpg               0
# 1   1000092795.jpg               1
# 2   1000092795.jpg               2
# 3   1000092795.jpg               3
# 4   1000092795.jpg               4
# 5     10002456.jpg               0
# 6     10002456.jpg               1
# 7     10002456.jpg               2
# 8     10002456.jpg               3
# 9     10002456.jpg               4
# 10  1000268201.jpg               0
# 11  1000268201.jpg               1
# 12  1000268201.jpg               2
# 13  1000268201.jpg               3
# 14  1000268201.jpg               4
# 15  1000344755.jpg               0
# 16  1000344755.jpg               1
# 17  1000344755.jpg               2
# 18  1000344755.jpg               3
# 19  1000344755.jpg               4
#
#                                              comment;
# 0    Two young guys with shaggy hair look at their...
# 1    Two young  White males are outside near many ...
# 2    Two men in green shirts are standing in a yard .
# 3        A man in a blue shirt standing in a garden .
# 4             Two friends enjoy time spent together .
# 5    Several men in hard hats are operating a gian...
# 6    Workers look down from up above on a piece of...
# 7    Two men working on a machine wearing hard hats .
# 8               Four men on top of a tall structure .
# 9                          Three men on a large rig .
# 10   A child in a pink dress is climbing up a set ...
# 11   A little girl in a pink dress going into a wo...
# 12   A little girl climbing the stairs to her play...
# 13    A little girl climbing into a wooden playhouse
# 14              A girl going into a wooden building .
# 15   Someone in a blue shirt and hat is standing o...
# 16   A man in a blue shirt is standing on a ladder...
# 17   A man on a ladder cleans the window of a tall...
# 18   man in blue shirt and jeans on ladder cleanin...
# 19                  a man on a ladder cleans a window

# %%
df['image_name'] = df['image_name'].str.strip()
df.head()
# Out:
#        image_name  comment_number  \
# 0  1000092795.jpg               0
# 1  1000092795.jpg               1
# 2  1000092795.jpg               2
# 3  1000092795.jpg               3
# 4  1000092795.jpg               4
#
#                                             comment;
# 0   Two young guys with shaggy hair look at their...
# 1   Two young  White males are outside near many ...
# 2   Two men in green shirts are standing in a yard .
# 3       A man in a blue shirt standing in a garden .
# 4            Two friends enjoy time spent together .

# %%
print(df.columns)
# Out:
# Index(['image_name', ' comment_number', ' comment;'], dtype='object')

# %%
import nltk
import os
# Path to your virtual environment's nltk_data directory
nltk_data_path = os.path.join('venv', 'nltk_data')

# Ensure the directory exists
os.makedirs(nltk_data_path, exist_ok=True)

# Add this path to NLTK's data paths
nltk.data.path.append(nltk_data_path)

# Download punkt
nltk.download('punkt', download_dir=nltk_data_path)
# Out:
# [nltk_data] Downloading package punkt to venv\nltk_data...
# [nltk_data]   Unzipping tokenizers\punkt.zip.
# True

# %%
def preprocess_caption(caption):
    # Lowercase
    caption = caption.lower()
    # Tokenize
    tokens = nltk.word_tokenize(caption)
    # Join tokens
    return " ".join(tokens)

# Apply preprocessing
df['cleaned_caption'] = df[' comment;'].apply(preprocess_caption)
df['cleaned_caption'].head()
# Out:
# ---------------------------------------------------------------------------
# LookupError                               Traceback (most recent call last)
# Cell In[12], line 10
#       7     return " ".join(tokens)
#       9 # Apply preprocessing
# ---> 10 df['cleaned_caption'] = df[' comment;'].apply(preprocess_caption)
#      11 df['cleaned_caption'].head()
#
# File c:\Users\sara0\Desktop\uni\THIRD YEAR\VISION AND LEARNING\Cloned repository Challenge 3\Image-Captioning\venv\Lib\site-packages\pandas\core\series.py:4924, in Series.apply(self, func, convert_dtype, args, by_row, **kwargs)
#    4789 def apply(
#    4790     self,
#    4791     func: AggFuncType,
#    (...)
#    4796     **kwargs,
#    4797 ) -> DataFrame | Series:
#    4798     """
#    4799     Invoke function on values of Series.
#    4800
#    (...)
#    4915     dtype: float64
#    4916     """
#    4917     return SeriesApply(
#    4918         self,
#    4919         func,
#    4920         convert_dtype=convert_dtype,
#    4921         by_row=by_row,
#    4922         args=args,
#    4923         kwargs=kwargs,
# -> 4924     ).apply()
#
# File c:\Users\sara0\Desktop\uni\THIRD YEAR\VISION AND LEARNING\Cloned repository Challenge 3\Image-Captioning\venv\Lib\site-packages\pandas\core\apply.py:1427, in SeriesApply.apply(self)
#    1424     return self.apply_compat()
#    1426 # self.func is Callable
# -> 1427 return self.apply_standard()
#
# File c:\Users\sara0\Desktop\uni\THIRD YEAR\VISION AND LEARNING\Cloned repository Challenge 3\Image-Captioning\venv\Lib\site-packages\pandas\core\apply.py:1507, in SeriesApply.apply_standard(self)
#    1501 # row-wise access
#    1502 # apply doesn't have a `na_action` keyword and for backward compat reasons
#    1503 # we need to give `na_action="ignore"` for categorical data.
#    1504 # TODO: remove the `na_action="ignore"` when that default has been changed in
#    1505 #  Categorical (GH51645).
#    1506 action = "ignore" if isinstance(obj.dtype, CategoricalDtype) else None
# -> 1507 mapped = obj._map_values(
#    1508     mapper=curried, na_action=action, convert=self.convert_dtype
#    1509 )
#    1511 if len(mapped) and isinstance(mapped[0], ABCSeries):
#    1512     # GH#43986 Need to do list(mapped) in order to get treated as nested
#    1513     #  See also GH#25959 regarding EA support
#    1514     return obj._constructor_expanddim(list(mapped), index=obj.index)
#
# File c:\Users\sara0\Desktop\uni\THIRD YEAR\VISION AND LEARNING\Cloned repository Challenge 3\Image-Captioning\venv\Lib\site-packages\pandas\core\base.py:921, in IndexOpsMixin._map_values(self, mapper, na_action, convert)
#     918 if isinstance(arr, ExtensionArray):
#     919     return arr.map(mapper, na_action=na_action)
# --> 921 return algorithms.map_array(arr, mapper, na_action=na_action, convert=convert)
#
# File c:\Users\sara0\Desktop\uni\THIRD YEAR\VISION AND LEARNING\Cloned repository Challenge 3\Image-Captioning\venv\Lib\site-packages\pandas\core\algorithms.py:1743, in map_array(arr, mapper, na_action, convert)
#    1741 values = arr.astype(object, copy=False)
#    1742 if na_action is None:
# -> 1743     return lib.map_infer(values, mapper, convert=convert)
#    1744 else:
#    1745     return lib.map_infer_mask(
#    1746         values, mapper, mask=isna(values).view(np.uint8), convert=convert
#    1747     )
#
# File lib.pyx:2972, in pandas._libs.lib.map_infer()
#
# Cell In[12], line 5, in preprocess_caption(caption)
#       3 caption = caption.lower()
#       4 # Tokenize
# ----> 5 tokens = nltk.word_tokenize(caption)
#       6 # Join tokens
#       7 return " ".join(tokens)
#
# File c:\Users\sara0\Desktop\uni\THIRD YEAR\VISION AND LEARNING\Cloned repository Challenge 3\Image-Captioning\venv\Lib\site-packages\nltk\tokenize\__init__.py:142, in word_tokenize(text, language, preserve_line)
#     127 def word_tokenize(text, language="english", preserve_line=False):
#     128     """
#     129     Return a tokenized copy of *text*,
#     130     using NLTK's recommended word tokenizer
#    (...)
#     140     :type preserve_line: bool
#     141     """
# --> 142     sentences = [text] if preserve_line else sent_tokenize(text, language)
#     143     return [
#     144         token for sent in sentences for token in _treebank_word_tokenizer.tokenize(sent)
#     145     ]
#
# File c:\Users\sara0\Desktop\uni\THIRD YEAR\VISION AND LEARNING\Cloned repository Challenge 3\Image-Captioning\venv\Lib\site-packages\nltk\tokenize\__init__.py:119, in sent_tokenize(text, language)
#     109 def sent_tokenize(text, language="english"):
#     110     """
#     111     Return a sentence-tokenized copy of *text*,
#     112     using NLTK's recommended sentence tokenizer
#    (...)
#     117     :param language: the model name in the Punkt corpus
#     118     """
# --> 119     tokenizer = _get_punkt_tokenizer(language)
#     120     return tokenizer.tokenize(text)
#
# File c:\Users\sara0\Desktop\uni\THIRD YEAR\VISION AND LEARNING\Cloned repository Challenge 3\Image-Captioning\venv\Lib\site-packages\nltk\tokenize\__init__.py:105, in _get_punkt_tokenizer(language)
#      96 @functools.lru_cache
#      97 def _get_punkt_tokenizer(language="english"):
#      98     """
#      99     A constructor for the PunktTokenizer that utilizes
#     100     a lru cache for performance.
#    (...)
#     103     :type language: str
#     104     """
# --> 105     return PunktTokenizer(language)
#
# File c:\Users\sara0\Desktop\uni\THIRD YEAR\VISION AND LEARNING\Cloned repository Challenge 3\Image-Captioning\venv\Lib\site-packages\nltk\tokenize\punkt.py:1744, in PunktTokenizer.__init__(self, lang)
#    1742 def __init__(self, lang="english"):
#    1743     PunktSentenceTokenizer.__init__(self)
# -> 1744     self.load_lang(lang)
#
# File c:\Users\sara0\Desktop\uni\THIRD YEAR\VISION AND LEARNING\Cloned repository Challenge 3\Image-Captioning\venv\Lib\site-packages\nltk\tokenize\punkt.py:1749, in PunktTokenizer.load_lang(self, lang)
#    1746 def load_lang(self, lang="english"):
#    1747     from nltk.data import find
# -> 1749     lang_dir = find(f"tokenizers/punkt_tab/{lang}/")
#    1750     self._params = load_punkt_params(lang_dir)
#    1751     self._lang = lang
#
# File c:\Users\sara0\Desktop\uni\THIRD YEAR\VISION AND LEARNING\Cloned repository Challenge 3\Image-Captioning\venv\Lib\site-packages\nltk\data.py:579, in find(resource_name, paths)
#     577 sep = "*" * 70
#     578 resource_not_found = f"\n{sep}\n{msg}\n{sep}\n"
# --> 579 raise LookupError(resource_not_found)
#
# LookupError:
# **********************************************************************
#   Resource punkt_tab not found.
#   Please use the NLTK Downloader to obtain the resource:
#
#   >>> import nltk
#   >>> nltk.download('punkt_tab')
#
#   For more information see: https://www.nltk.org/data.html
#
#   Attempted to load tokenizers/punkt_tab/english/
#
#   Searched in:
#     - 'C:\\Users\\sara0/nltk_data'
#     - 'c:\\Users\\sara0\\Desktop\\uni\\THIRD YEAR\\VISION AND LEARNING\\Cloned repository Challenge 3\\Image-Captioning\\venv\\nltk_data'
#     - 'c:\\Users\\sara0\\Desktop\\uni\\THIRD YEAR\\VISION AND LEARNING\\Cloned repository Challenge 3\\Image-Captioning\\venv\\share\\nltk_data'
#     - 'c:\\Users\\sara0\\Desktop\\uni\\THIRD YEAR\\VISION AND LEARNING\\Cloned repository Challenge 3\\Image-Captioning\\venv\\lib\\nltk_data'
#     - 'C:\\Users\\sara0\\AppData\\Roaming\\nltk_data'
#     - 'C:\\nltk_data'
#     - 'D:\\nltk_data'
#     - 'E:\\nltk_data'
#     - 'venv\\nltk_data'
# **********************************************************************
